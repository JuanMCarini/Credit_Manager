# %% [markdown]
# # Work Area

# %%
import pandas as pd

import str.database.create as create_db
import str.database.structure as db_structure
import str.database.get as get
import str.database.new as new_entry

from str.database.connection import engine

from importlib import reload

outputs = True

# %%
reload(create_db)

reload(db_structure)
reload(get)
reload(new_entry)
# Out:
# ✔️ Base de datos creada correctamente.
#
# ✔️ Tabla 'genders' actualizada correctamente.
#
# ✔️ Tabla 'marital_status' actualizada correctamente.
#
# ✔️ Tabla 'credit_types' actualizada correctamente.
#
# ✔️ Sistema inicializado correctamente a nombre de Credise S.A..

# %%
pd.read_sql('credits', engine)
# Out:
#    ID Origin_ID Disbursement_Date First_Due_Date  Amount_Disbursed    Capital  \
# 0   1      None        2025-11-12     2026-01-28         1000000.0  1000000.0
#
#    Credit_Type_ID  TNA_C_IVA  Term  Client_ID  Organism_ID Purchase_ID Sale_ID
# 0               1        1.5    12          1            1        None    None
