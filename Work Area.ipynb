# %% [markdown]
# # Work Area

# %%
import pandas as pd

from sqlalchemy import text
from sqlalchemy.exc import SQLAlchemyError

import str.database.connection as db_connection
import str.database.create as create_db
import str.tool as tool

from str.database.connection import engine, base
from str.tool import _log

from importlib import reload

# reload(create_db)
outputs = True
# Out:
# ✔️ Base de datos creada correctamente.
#
# ✔️ Tabla 'gender' actualizada correctamente.
#
# ✔️ Tabla 'marital_status' actualizada correctamente.
#
# ✔️ Sistema inicializado correctamente a nombre de Credise S.A..
