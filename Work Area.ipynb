# %% [markdown]
# # Work Area

# %%
import pandas as pd

from importlib import reload

from str.database.connection import read_table
import str.database.create as db_creating
import str.categories.generator as gen_cat
import str.categories as categories
import str.tool as tool
import str.example as example

reload(categories)
reload(gen_cat)
reload(db_creating)
reload(example);
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       3 from importlib import reload
#       5 from str.database.connection import read_table
# ----> 6 import str.database.create as db_creating
#       7 import str.categories.generator as gen_cat
#       8 import str.categories as categories
#
# File c:\Users\juanm\Repositorios\Credit_Manager\str\database\create.py:17
#       8 from str.categories.main import (
#       9     COLLECTION_TYPES,
#      10     CREDIT_TYPES,
#    (...)     14     RELATIONSHIPS_TYPES,
#      15 )
#      16 from str.database.connection import ENGINE, read_table, write_table
# ---> 17 from str.database.structure import (
#      18     City,
#      19     Country,
#      20     Province,
#      21 )
#      22 from str.tool import _log, log
#      24 # Leer el contenido del archivo .sql
#
# File c:\Users\juanm\Repositorios\Credit_Manager\str\database\structure\__init__.py:14
#      12 from str.database.structure.clients.phones import ClientPhones
#      13 from str.database.structure.countries import Country
# ---> 14 from str.database.structure.credits import Credit
#      15 from str.database.structure.installments import Installment
#      16 from str.database.structure.lines import Line
#
# File c:\Users\juanm\Repositorios\Credit_Manager\str\database\structure\credits.py:11
#       6 from str.database.connection import read_table, write_table
#       7 from str.database.structure import (
#       8     Client,
#       9     search_client_id,
#      10 )
# ---> 11 from str.database.structure.installments import Installment
#      12 from str.database.structure.organisms import Organism, search_organism_id
#      13 from str.tool import _log, log
#
# File c:\Users\juanm\Repositorios\Credit_Manager\str\database\structure\installments.py:5
#       2 from pandas import DataFrame, Period
#       4 from str.database.connection import read_table, write_table
# ----> 5 from str.database.create import OUR_COMPANY_ID
#       8 class Installment:
#       9     def _to_dict(self) -> dict:
#
# ImportError: cannot import name 'OUR_COMPANY_ID' from partially initialized module 'str.database.create' (most likely due to a circular import) (c:\Users\juanm\Repositorios\Credit_Manager\str\database\create.py)

# %%
read_table('credit_types')
# Out:
#        Name
# ID
# 1   FRANCES
# 2    ALEMAN
# 3   PENALTY

# %%
df_crts = read_table('credits')

df_crts.head()
# Out:
#     Origin_ID Disbursement_Date First_Due_Date  Capital_Requested  Capital  \
# ID
# 1           1        2025-11-17     2026-01-28           100000.0  95000.0
#
#     Credit_Type_ID  TNA_C_IVA  Term  Client_ID  Organism_ID  Purchase_ID  \
# ID
# 1                1        1.3    12          1            1         <NA>
#
#     Sale_ID
# ID
# 1      <NA>

# %%
df_inst = read_table('installments')

df_inst
# Out:
#     Credit_ID  Inst_Num  Owner_ID    Due_Date       Capital     Interest  \
# ID
# 1           1         1         1  2026-01-28   4262.967720  8388.995811
# 2           1         2         1  2026-02-28   4718.462901  8012.553513
# 3           1         3         1  2026-03-28   5222.627431  7595.888613
# 4           1         4         1  2026-04-28   5780.661594  7134.703353
# 5           1         5         1  2026-05-28   6398.321326  6624.240765
# 6           1         6         1  2026-06-28   7081.977578  6059.235598
# 7           1         7         1  2026-07-28   7838.682031  5433.860017
# 8           1         8         1  2026-08-28   8676.239837  4741.663483
# 9           1         9         1  2026-09-28   9603.290121  3975.506224
# 10          1        10         1  2026-10-28  10629.395093  3127.485586
# 11          1        11         1  2026-11-28  11765.138678  2188.854523
# 12          1        12         1  2026-12-28  13022.235688  1149.931375
#
#             IVA         Total Settlement_Date
# ID
# 1   1761.689120  14413.652652      2026-01-28
# 2   1682.636238  14413.652652      2026-02-28
# 3   1595.136609  14413.652652      2026-03-28
# 4   1498.287704  14413.652652      2026-04-28
# 5   1391.090561  14413.652652      2026-05-28
# 6   1272.439476  14413.652652      2026-06-28
# 7   1141.110604  14413.652652      2026-07-28
# 8    995.749331  14413.652652      2026-08-28
# 9    834.856307  14413.652652      2026-09-28
# 10   656.771973  14413.652652      2026-10-28
# 11   459.659450  14413.652652      2026-11-28
# 12   241.485589  14413.652652      2026-12-28
